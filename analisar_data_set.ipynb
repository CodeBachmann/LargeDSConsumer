# %%
import pandas as pd

# %%
file_path = r"C:\Users\320284019\Desktop\BSAR CONCILIÇÕES\TesteComBigData\BackEnd\Processamento\FIles\deletions\deletions.csv"
df = pd.read_csv(file_path, nrows=1000, skiprows=9560)

# %%
df.head(10)
# Out:
#    1286003161000          /user/validator_bot  1364626061004  \
# 0  1358079930004              /user/googlebot  1364717869000
# 1  1227300543000  /user/content_administrator  1336794576001
# 2  1326031226000        /user/fda_medical_bot  1326307869002
# 3  1306174053000         /user/wikipedia_intl  1361053573004
# 4  1261224964001               /user/book_bot  1268099935002
# 5  1172014045010           /user/mwcl_chefmoz  1341523148000
# 6  1205538469000            /user/mwcl_images  1335970519000
# 7  1219158921001            /user/mw_prop_bot  1339520548000
# 8  1360089592001          /user/wikirecon_bot  1360482433000
# 9  1304854077000           /user/mw_tally_bot  1304940443000
#
#    /user/mbz_pipeline_merge_bot  /m/037ylw3  \
# 0  /user/mbz_pipeline_merge_bot   /m/0tszlf
# 1              /user/delete_bot  /m/04xx97m
# 2           /user/validator_bot  /m/0hqgpmr
# 3           /user/wikirecon_bot    /m/0cl7h
# 4           /user/validator_bot   /m/02glnq
# ...
